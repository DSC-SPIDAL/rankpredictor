# %% [markdown]
# ### stage_model_regressor
#
# prediction models of chg_of_rank_in_stage on stage dataset
#
# data format:
#     target , eventid ,    car_number,    stageid,     features...

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# to use only one GPU.
# use this on r-001
# otherwise comment
import os
#os.environ["CUDA_VISIBLE_DEVICES"]="7"

# %%
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble.forest import RandomForestRegressor
from sklearn.linear_model.ridge import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model.stochastic_gradient import SGDRegressor
from sklearn.svm.classes import SVR
from sklearn.utils import shuffle
from sklearn import metrics
import xgboost as xgb

# %%
# bulid regression model
regressors = ['currank','avgrank','dice','lasso','ridge','rf','svr','xgb']
def get_regressor(regressor = 'lr'):
    if regressor == "lasso":
        clf = LassoCV(cv=5, random_state=0)
    elif regressor == "ridge":
        clf = RidgeCV(alphas=np.logspace(-6, 6, 13))
    elif regressor == "rf":
        clf = RandomForestRegressor(n_estimators=100)
    elif regressor == 'svr':
        clf = SVR(kernel='rbf')
    elif regressor == 'xgb':
        clf = xgb.XGBRegressor(objective="reg:linear", random_state=42, max_depth=3)
    elif regressor == 'dice':
        clf = RandomDice('1234')
    elif regressor == 'currank':
        clf = CurRank()
    elif regressor == 'avgrank':
        clf = AverageRank()        
    else:
        clf = None
        
    return clf


class CurRank():
    """
    predict with current rank
    """
    def __init__(self):
        pass
    def fit(self, x, y):
        pass
    def predict(self, test_x):
        pred_y = [0 for x in range(test_x.shape[0])]
        return np.array(pred_y)
    
class AverageRank():
    """
    print('[*] predict with average rankchg (change_in_rank_all):idx = 15')
    change_in_rank_all = test[:,15]
    pred_y_avg = np.array([1 if x > 0 else (-1 if x < 0 else 0) for x in change_in_rank_all])
    """
    def __init__(self):
        pass
    def fit(self, x, y):
        pass
    def predict(self, test_x):
        pred_y = []
        for x in test_x:
            #13, change_in_rank_all
            pred_y.append(x[13])
        #pred_y_avg = np.array([1 if x > 0 else (-1 if x < 0 else 0) for x in pred_y])
        pred_y_avg = pred_y
        return np.array(pred_y_avg)   

class RandomDice():
    """
    a random dice model
    """
    def __init__(self, seed='1234'):
        self.dist = []
        self.val = []
        random.seed(seed)
    
    def fit(self, x, y):
        total = y.shape[0]
        yval = set(y)
        
        ratio = 0.
        for val in yval:
            self.val.append(val)
            ratio += np.sum(y==val)*1.0 / total
            self.dist.append(ratio)
            
    def predict(self, test_x):
        pred_y = []
        for x in test_x:
            dice = random.random()
            #search in self.dist
            find_idx = -1
            for idx, ratio in enumerate(self.dist):
                if dice <= ratio:
                    find_idx = idx
                    break
            
            #or the last one match
            pred_y.append(self.val[find_idx])
            
        return np.array(pred_y)

def evaluate(test_y, pred_y):
    mae = metrics.mean_absolute_error(test_y, pred_y) 
    rmse = math.sqrt(metrics.mean_squared_error(test_y, pred_y))
    r2 = metrics.r2_score(test_y, pred_y)
    print('rmse=%.2f, mae=%.2f, r2=%.2f'%(rmse, mae, r2))
    return rmse, mae, r2
    
#
#features
#    cols=[Myidx, 'target','eventid','car_number','stageid',
#             'firststage','pit_in_caution','start_position',
#             'start_rank','start_rank_ratio','top_pack','bottom_pack',
#             'average_rank','average_rank_all',
#             'change_in_rank','change_in_rank_all','rate_of_change','rate_of_change_all']    
def split_by_eventid(stagedata, eventid):
    """
    split by eventid
    """
    #if not eventid in stagedata:
    #    print('error, %d not found in stagedata'%eventid)
    #    return
    
    train = stagedata[stagedata['eventid'] != eventid].to_numpy()
    test  = stagedata[stagedata['eventid'] == eventid].to_numpy()

    #2:car_number
    train_x = train[:,2:]
    #train_y = np.array([1 if x > 0 else (-1 if x < 0 else 0) for x in train[:,1]])
    train_y = train[:,1]
    test_x = test[:,2:]
    #test_y = np.array([1 if x > 0 else (-1 if x < 0 else 0) for x in test[:,1]])
    test_y = test[:,1]
    
    return train, test, train_x, train_y, test_x, test_y


def split_by_stageid(stagedata, stageid):
    """
    split by stageid
    """
    #if not eventid in stagedata:
    #    print('error, %d not found in stagedata'%eventid)
    #    return
    
    train = stagedata[stagedata['stageid'] <= stageid].to_numpy()
    test  = stagedata[stagedata['stageid'] > stageid].to_numpy()

    train_x = train[:,2:]
    #train_y = np.array([1 if x > 0 else (-1 if x < 0 else 0) for x in train[:,1]])
    train_y = train[:,1]
    test_x = test[:,2:]
    #test_y = np.array([1 if x > 0 else (-1 if x < 0 else 0) for x in test[:,1]])
    test_y = test[:,1]
    
    return train, test, train_x, train_y, test_x, test_y


def regressor_model(name='svr'):
    ### test learning models
    print('[*] predict with %s model'%name)
    clf = get_regressor(name)
    clf.fit(train_x, train_y)

    pred_y = clf.predict(test_x)
    score = evaluate(test_y, pred_y)
    return score

# %%
#load data
suffix='-withneighbor-newfeatures-timediff'
stagedata = pd.read_csv('stage-2018%s.csv'%suffix)
stagedata.fillna(0, inplace=True)
stagedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805 entries, 0 to 804
# Data columns (total 35 columns):
# Unnamed: 0                   805 non-null int64
# target                       805 non-null int64
# eventid                      805 non-null int64
# car_number                   805 non-null int64
# stageid                      805 non-null int64
# firststage                   805 non-null int64
# pit_in_caution               805 non-null int64
# start_position               805 non-null int64
# start_rank                   805 non-null int64
# start_rank_ratio             805 non-null float64
# top_pack                     805 non-null int64
# bottom_pack                  805 non-null int64
# average_rank                 805 non-null float64
# average_rank_all             805 non-null float64
# change_in_rank               805 non-null int64
# change_in_rank_all           805 non-null float64
# rate_of_change               805 non-null int64
# rate_of_change_all           805 non-null float64
# laptime_green_mean_prev      805 non-null float64
# laptime_green_std_prev       805 non-null float64
# laptime_green_mean_all       805 non-null float64
# laptime_green_std_all        805 non-null float64
# laptime_mean_prev            805 non-null float64
# laptime_std_prev             805 non-null float64
# laptime_mean_all             805 non-null float64
# laptime_std_all              805 non-null float64
# laps_prev                    805 non-null int64
# laps_after_last_pitstop      805 non-null int64
# pittime_prev                 805 non-null float64
# prev_nb0_change_in_rank      805 non-null int64
# prev_nb1_change_in_rank      805 non-null int64
# prev_nb2_change_in_rank      805 non-null int64
# follow_nb0_change_in_rank    805 non-null int64
# follow_nb1_change_in_rank    805 non-null int64
# follow_nb2_change_in_rank    805 non-null int64
# dtypes: float64(14), int64(21)
# memory usage: 220.2 KB

# %% [markdown]
# ### model on data split by event

# %%
cols = ['runid','trainsize','testsize','testdistribution']
cols.extend(regressors)
print('cols:%s'%cols)
retdf0 = pd.DataFrame([],columns=cols)
retdf1 = pd.DataFrame([],columns=cols)

eventsname = ['Phoenix','Indy500','Texas','Iowa','Pocono','Gateway']
events = set(stagedata['eventid'])
for eventid in events:
    print('Testset = %s'%eventsname[eventid])
    
    train, test, train_x, train_y, test_x, test_y = split_by_eventid(stagedata, eventid)
    test_distribution = '+:%d,0:%d,-:%d'%(np.sum(test_y>0),np.sum(test_y==0),np.sum(test_y<0))
    #print('Testset by stageid= %s, trainsize=%d, testsize=%d, dist=%s'%
    #      (stageid, train_x.shape[0], test_x.shape[0], test_distribution))
    
    #record
    rec0 = [eventsname[eventid],train_x.shape[0],test_x.shape[0],test_distribution]
    rec1 = [eventsname[eventid],train_x.shape[0],test_x.shape[0],test_distribution]
    
    acc0 = [0 for x in range(len(regressors))]
    acc1 = [0 for x in range(len(regressors))]
    for idx, clf in enumerate(regressors):
        acc0[idx] = regressor_model(clf)[0]
        acc1[idx] = regressor_model(clf)[2]

    rec0.extend(acc0)
    rec1.extend(acc1)
    #print('rec:%s'%rec)
    
    #new df
    df = pd.DataFrame([rec0],columns=cols)
    retdf0 = pd.concat([retdf0, df])        
    
    df = pd.DataFrame([rec1],columns=cols)
    retdf1 = pd.concat([retdf1, df])        

    
retdf0.to_csv('regressors_stagedata_splitbyevent%s_rmse.csv'%suffix)
retdf1.to_csv('regressors_stagedata_splitbyevent%s_r2.csv'%suffix)

df_event_rmse = retdf0
df_event_r2 = retdf1
# Out:
# cols:['runid', 'trainsize', 'testsize', 'testdistribution', 'currank', 'avgrank', 'dice', 'lasso', 'ridge', 'rf', 'svr', 'xgb']
# Testset = Phoenix
# [*] predict with currank model
# rmse=5.43, mae=3.66, r2=-0.00
# [*] predict with currank model
# rmse=5.43, mae=3.66, r2=-0.00
# [*] predict with avgrank model
# rmse=6.77, mae=4.63, r2=-0.56
# [*] predict with avgrank model
# rmse=6.77, mae=4.63, r2=-0.56
# [*] predict with dice model
# rmse=7.16, mae=5.38, r2=-0.74
# [*] predict with dice model
# rmse=7.16, mae=5.38, r2=-0.74
# [*] predict with lasso model
# rmse=4.98, mae=3.51, r2=0.16
# [*] predict with lasso model
# rmse=4.98, mae=3.51, r2=0.16
# [*] predict with ridge model
# rmse=5.03, mae=3.57, r2=0.14
# [*] predict with ridge model
# rmse=5.03, mae=3.57, r2=0.14
# [*] predict with rf model
# rmse=5.09, mae=3.77, r2=0.12
# [*] predict with rf model
# rmse=4.99, mae=3.59, r2=0.16
# [*] predict with svr model
# rmse=5.42, mae=3.66, r2=0.00
# [*] predict with svr model
# rmse=5.42, mae=3.66, r2=0.00
# [*] predict with xgb model
# /scratch/hpda/anaconda3/envs/py2/lib/python2.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# rmse=5.11, mae=3.65, r2=0.11
# [*] predict with xgb model
# rmse=5.11, mae=3.65, r2=0.11
# Testset = Indy500
# [*] predict with currank model
# rmse=5.75, mae=4.32, r2=-0.00
# [*] predict with currank model
# rmse=5.75, mae=4.32, r2=-0.00
# [*] predict with avgrank model
# rmse=7.33, mae=5.59, r2=-0.63
# [*] predict with avgrank model
# rmse=7.33, mae=5.59, r2=-0.63
# [*] predict with dice model
# rmse=6.83, mae=5.26, r2=-0.42
# [*] predict with dice model
# rmse=6.83, mae=5.26, r2=-0.42
# [*] predict with lasso model
# rmse=5.48, mae=4.36, r2=0.09
# [*] predict with lasso model
# rmse=5.48, mae=4.36, r2=0.09
# [*] predict with ridge model
# rmse=5.48, mae=4.28, r2=0.09
# [*] predict with ridge model
# rmse=5.48, mae=4.28, r2=0.09
# [*] predict with rf model
# rmse=5.59, mae=4.25, r2=0.05
# [*] predict with rf model
# rmse=5.51, mae=4.17, r2=0.08
# [*] predict with svr model
# rmse=5.75, mae=4.32, r2=-0.00
# [*] predict with svr model
# rmse=5.75, mae=4.32, r2=-0.00
# [*] predict with xgb model
# rmse=5.60, mae=4.27, r2=0.05
# [*] predict with xgb model
# rmse=5.60, mae=4.27, r2=0.05
# Testset = Texas
# [*] predict with currank model
# rmse=4.63, mae=2.85, r2=-0.01
# [*] predict with currank model
# rmse=4.63, mae=2.85, r2=-0.01
# [*] predict with avgrank model
# rmse=6.54, mae=4.53, r2=-1.01
# [*] predict with avgrank model
# rmse=6.54, mae=4.53, r2=-1.01
# [*] predict with dice model
# rmse=6.46, mae=4.59, r2=-0.96
# [*] predict with dice model
# rmse=6.46, mae=4.59, r2=-0.96
# [*] predict with lasso model
# rmse=4.47, mae=3.11, r2=0.06
# [*] predict with lasso model
# rmse=4.47, mae=3.11, r2=0.06
# [*] predict with ridge model
# rmse=4.76, mae=3.51, r2=-0.06
# [*] predict with ridge model
# rmse=4.76, mae=3.51, r2=-0.06
# [*] predict with rf model
# rmse=5.14, mae=3.90, r2=-0.24
# [*] predict with rf model
# rmse=5.13, mae=3.91, r2=-0.24
# [*] predict with svr model
# rmse=4.53, mae=2.83, r2=0.04
# [*] predict with svr model
# rmse=4.53, mae=2.83, r2=0.04
# [*] predict with xgb model
# rmse=4.91, mae=3.71, r2=-0.13
# [*] predict with xgb model
# rmse=4.91, mae=3.71, r2=-0.13
# Testset = Iowa
# [*] predict with currank model
# rmse=3.60, mae=2.51, r2=0.00
# [*] predict with currank model
# rmse=3.60, mae=2.51, r2=0.00
# [*] predict with avgrank model
# rmse=4.91, mae=3.49, r2=-0.86
# [*] predict with avgrank model
# rmse=4.91, mae=3.49, r2=-0.86
# [*] predict with dice model
# rmse=5.91, mae=4.39, r2=-1.69
# [*] predict with dice model
# rmse=5.91, mae=4.39, r2=-1.69
# [*] predict with lasso model
# rmse=3.41, mae=2.51, r2=0.10
# [*] predict with lasso model
# rmse=3.41, mae=2.51, r2=0.10
# [*] predict with ridge model
# rmse=3.49, mae=2.56, r2=0.06
# [*] predict with ridge model
# rmse=3.49, mae=2.56, r2=0.06
# [*] predict with rf model
# rmse=4.13, mae=3.26, r2=-0.32
# [*] predict with rf model
# rmse=4.04, mae=3.28, r2=-0.26
# [*] predict with svr model
# rmse=3.60, mae=2.56, r2=0.00
# [*] predict with svr model
# rmse=3.60, mae=2.56, r2=0.00
# [*] predict with xgb model
# rmse=3.71, mae=2.91, r2=-0.06
# [*] predict with xgb model
# rmse=3.71, mae=2.91, r2=-0.06
# Testset = Pocono
# [*] predict with currank model
# rmse=2.81, mae=1.75, r2=-0.03
# [*] predict with currank model
# rmse=2.81, mae=1.75, r2=-0.03
# [*] predict with avgrank model
# rmse=3.52, mae=2.43, r2=-0.62
# [*] predict with avgrank model
# rmse=3.52, mae=2.43, r2=-0.62
# [*] predict with dice model
# rmse=5.13, mae=3.86, r2=-2.44
# [*] predict with dice model
# rmse=5.13, mae=3.86, r2=-2.44
# [*] predict with lasso model
# /scratch/hpda/anaconda3/envs/py2/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# rmse=3.00, mae=2.30, r2=-0.18
# [*] predict with lasso model
# rmse=3.00, mae=2.30, r2=-0.18
# [*] predict with ridge model
# rmse=3.36, mae=2.45, r2=-0.47
# [*] predict with ridge model
# rmse=3.36, mae=2.45, r2=-0.47
# [*] predict with rf model
# rmse=3.00, mae=2.29, r2=-0.17
# [*] predict with rf model
# rmse=3.28, mae=2.58, r2=-0.40
# [*] predict with svr model
# rmse=2.81, mae=1.88, r2=-0.03
# [*] predict with svr model
# rmse=2.81, mae=1.88, r2=-0.03
# [*] predict with xgb model
# rmse=2.83, mae=2.12, r2=-0.04
# [*] predict with xgb model
# rmse=2.83, mae=2.12, r2=-0.04
# Testset = Gateway
# [*] predict with currank model
# rmse=3.12, mae=2.14, r2=-0.00
# [*] predict with currank model
# rmse=3.12, mae=2.14, r2=-0.00
# [*] predict with avgrank model
# rmse=4.34, mae=3.10, r2=-0.93
# [*] predict with avgrank model
# rmse=4.34, mae=3.10, r2=-0.93
# [*] predict with dice model
# rmse=5.69, mae=3.93, r2=-2.32
# [*] predict with dice model
# rmse=5.69, mae=3.93, r2=-2.32
# [*] predict with lasso model
# rmse=2.98, mae=2.22, r2=0.09
# [*] predict with lasso model
# rmse=2.98, mae=2.22, r2=0.09
# [*] predict with ridge model
# rmse=3.06, mae=2.31, r2=0.04
# [*] predict with ridge model
# rmse=3.06, mae=2.31, r2=0.04
# [*] predict with rf model
# rmse=3.21, mae=2.40, r2=-0.06
# [*] predict with rf model
# rmse=3.17, mae=2.34, r2=-0.03
# [*] predict with svr model
# rmse=3.10, mae=2.20, r2=0.02
# [*] predict with svr model
# rmse=3.10, mae=2.20, r2=0.02
# [*] predict with xgb model
# rmse=3.10, mae=2.33, r2=0.02
# [*] predict with xgb model
# rmse=3.10, mae=2.33, r2=0.02

# %% [markdown]
# ### model on data split by stage

# %%
retdf0 = pd.DataFrame([],columns=cols)
retdf1 = pd.DataFrame([],columns=cols)

for stageid in range(8):
    train, test, train_x, train_y, test_x, test_y =split_by_stageid(stagedata, stageid)
    test_distribution = '+:%d,0:%d,-:%d'%(np.sum(test_y>0),np.sum(test_y==0),np.sum(test_y<0))
    #print('Testset by stageid= %s, trainsize=%d, testsize=%d, dist=%s'%
    #      (stageid, train_x.shape[0], test_x.shape[0], test_distribution))
    
    #record
    rec0 = ['stage%d'%stageid,train_x.shape[0],test_x.shape[0],test_distribution]
    rec1 = ['stage%d'%stageid,train_x.shape[0],test_x.shape[0],test_distribution]
    
    acc0 = [0 for x in range(len(regressors))]
    acc1 = [0 for x in range(len(regressors))]
    for idx, clf in enumerate(regressors):
        acc0[idx] = regressor_model(clf)[0]
        acc1[idx] = regressor_model(clf)[2]

    rec0.extend(acc0)
    rec1.extend(acc1)
    #print('rec:%s'%rec)
    
    #new df
    df = pd.DataFrame([rec0],columns=cols)
    retdf0 = pd.concat([retdf0, df])  
    
    df = pd.DataFrame([rec1],columns=cols)
    retdf1 = pd.concat([retdf1, df])  

retdf0.to_csv('regressor_stagedata_splitbystage%s_rmse.csv'%suffix)
retdf1.to_csv('regressor_stagedata_splitbystage%s_r2.csv'%suffix)

df_stage_rmse = retdf0
df_stage_r2 = retdf1
# Out:
# [*] predict with currank model
# rmse=4.36, mae=2.83, r2=-0.01
# [*] predict with currank model
# rmse=4.36, mae=2.83, r2=-0.01
# [*] predict with avgrank model
# rmse=6.11, mae=4.21, r2=-0.98
# [*] predict with avgrank model
# rmse=6.11, mae=4.21, r2=-0.98
# [*] predict with dice model
# rmse=6.93, mae=5.36, r2=-1.55
# [*] predict with dice model
# rmse=6.93, mae=5.36, r2=-1.55
# [*] predict with lasso model
# rmse=4.41, mae=3.08, r2=-0.03
# [*] predict with lasso model
# rmse=4.41, mae=3.08, r2=-0.03
# [*] predict with ridge model
# rmse=4.23, mae=3.05, r2=0.05
# [*] predict with ridge model
# rmse=4.23, mae=3.05, r2=0.05
# [*] predict with rf model
# rmse=4.81, mae=3.50, r2=-0.22
# [*] predict with rf model
# rmse=4.78, mae=3.53, r2=-0.21
# [*] predict with svr model
# rmse=4.38, mae=2.90, r2=-0.01
# [*] predict with svr model
# rmse=4.38, mae=2.90, r2=-0.01
# [*] predict with xgb model
# rmse=5.23, mae=3.83, r2=-0.45
# [*] predict with xgb model
# rmse=5.23, mae=3.83, r2=-0.45
# [*] predict with currank model
# rmse=3.98, mae=2.57, r2=-0.00
# [*] predict with currank model
# rmse=3.98, mae=2.57, r2=-0.00
# [*] predict with avgrank model
# rmse=4.96, mae=3.45, r2=-0.56
# [*] predict with avgrank model
# rmse=4.96, mae=3.45, r2=-0.56
# [*] predict with dice model
# rmse=6.72, mae=4.96, r2=-1.86
# [*] predict with dice model
# rmse=6.72, mae=4.96, r2=-1.86
# [*] predict with lasso model
# rmse=3.78, mae=2.70, r2=0.10
# [*] predict with lasso model
# rmse=3.78, mae=2.70, r2=0.10
# [*] predict with ridge model
# rmse=3.74, mae=2.66, r2=0.11
# [*] predict with ridge model
# rmse=3.74, mae=2.66, r2=0.11
# [*] predict with rf model
# rmse=4.19, mae=3.22, r2=-0.11
# [*] predict with rf model
# rmse=4.13, mae=3.15, r2=-0.08
# [*] predict with svr model
# rmse=4.01, mae=2.65, r2=-0.02
# [*] predict with svr model
# rmse=4.01, mae=2.65, r2=-0.02
# [*] predict with xgb model
# rmse=4.12, mae=3.08, r2=-0.07
# [*] predict with xgb model
# rmse=4.12, mae=3.08, r2=-0.07
# [*] predict with currank model
# rmse=3.85, mae=2.39, r2=-0.00
# [*] predict with currank model
# rmse=3.85, mae=2.39, r2=-0.00
# [*] predict with avgrank model
# rmse=4.55, mae=3.07, r2=-0.40
# [*] predict with avgrank model
# rmse=4.55, mae=3.07, r2=-0.40
# [*] predict with dice model
# rmse=6.79, mae=5.04, r2=-2.13
# [*] predict with dice model
# rmse=6.79, mae=5.04, r2=-2.13
# [*] predict with lasso model
# rmse=3.56, mae=2.36, r2=0.14
# [*] predict with lasso model
# rmse=3.56, mae=2.36, r2=0.14
# [*] predict with ridge model
# rmse=3.52, mae=2.36, r2=0.16
# [*] predict with ridge model
# rmse=3.52, mae=2.36, r2=0.16
# [*] predict with rf model
# rmse=3.79, mae=2.60, r2=0.03
# [*] predict with rf model
# rmse=3.76, mae=2.59, r2=0.04
# [*] predict with svr model
# rmse=3.85, mae=2.45, r2=-0.00
# [*] predict with svr model
# rmse=3.85, mae=2.45, r2=-0.00
# [*] predict with xgb model
# rmse=3.88, mae=2.70, r2=-0.02
# [*] predict with xgb model
# rmse=3.88, mae=2.70, r2=-0.02
# [*] predict with currank model
# rmse=3.54, mae=2.00, r2=-0.00
# [*] predict with currank model
# rmse=3.54, mae=2.00, r2=-0.00
# [*] predict with avgrank model
# rmse=4.12, mae=2.64, r2=-0.36
# [*] predict with avgrank model
# rmse=4.12, mae=2.64, r2=-0.36
# [*] predict with dice model
# rmse=6.07, mae=4.54, r2=-1.95
# [*] predict with dice model
# rmse=6.07, mae=4.54, r2=-1.95
# [*] predict with lasso model
# rmse=3.33, mae=2.16, r2=0.11
# [*] predict with lasso model
# rmse=3.33, mae=2.16, r2=0.11
# [*] predict with ridge model
# rmse=3.30, mae=2.16, r2=0.13
# [*] predict with ridge model
# rmse=3.30, mae=2.16, r2=0.13
# [*] predict with rf model
# rmse=3.46, mae=2.37, r2=0.04
# [*] predict with rf model
# rmse=3.48, mae=2.37, r2=0.03
# [*] predict with svr model
# rmse=3.56, mae=2.12, r2=-0.01
# [*] predict with svr model
# rmse=3.56, mae=2.12, r2=-0.01
# [*] predict with xgb model
# rmse=3.67, mae=2.58, r2=-0.08
# [*] predict with xgb model
# rmse=3.67, mae=2.58, r2=-0.08
# [*] predict with currank model
# rmse=3.09, mae=1.81, r2=-0.05
# [*] predict with currank model
# rmse=3.09, mae=1.81, r2=-0.05
# [*] predict with avgrank model
# rmse=3.39, mae=2.22, r2=-0.26
# [*] predict with avgrank model
# rmse=3.39, mae=2.22, r2=-0.26
# [*] predict with dice model
# rmse=5.32, mae=4.11, r2=-2.12
# [*] predict with dice model
# rmse=5.32, mae=4.11, r2=-2.12
# [*] predict with lasso model
# rmse=2.92, mae=2.07, r2=0.06
# [*] predict with lasso model
# rmse=2.92, mae=2.07, r2=0.06
# [*] predict with ridge model
# rmse=2.91, mae=2.01, r2=0.07
# [*] predict with ridge model
# rmse=2.91, mae=2.01, r2=0.07
# [*] predict with rf model
# rmse=2.92, mae=2.01, r2=0.07
# [*] predict with rf model
# rmse=2.90, mae=1.98, r2=0.07
# [*] predict with svr model
# rmse=3.03, mae=1.86, r2=-0.01
# [*] predict with svr model
# rmse=3.03, mae=1.86, r2=-0.01
# [*] predict with xgb model
# rmse=2.99, mae=2.19, r2=0.02
# [*] predict with xgb model
# rmse=2.99, mae=2.19, r2=0.02
# [*] predict with currank model
# rmse=2.87, mae=1.61, r2=-0.04
# [*] predict with currank model
# rmse=2.87, mae=1.61, r2=-0.04
# [*] predict with avgrank model
# rmse=3.25, mae=2.12, r2=-0.34
# [*] predict with avgrank model
# rmse=3.25, mae=2.12, r2=-0.34
# [*] predict with dice model
# rmse=6.03, mae=4.44, r2=-3.63
# [*] predict with dice model
# rmse=6.03, mae=4.44, r2=-3.63
# [*] predict with lasso model
# rmse=2.61, mae=1.79, r2=0.14
# [*] predict with lasso model
# rmse=2.61, mae=1.79, r2=0.14
# [*] predict with ridge model
# rmse=2.68, mae=1.80, r2=0.08
# [*] predict with ridge model
# rmse=2.68, mae=1.80, r2=0.08
# [*] predict with rf model
# rmse=2.85, mae=1.84, r2=-0.04
# [*] predict with rf model
# rmse=2.90, mae=1.88, r2=-0.07
# [*] predict with svr model
# rmse=2.81, mae=1.69, r2=-0.00
# [*] predict with svr model
# rmse=2.81, mae=1.69, r2=-0.00
# [*] predict with xgb model
# rmse=3.09, mae=2.11, r2=-0.21
# [*] predict with xgb model
# rmse=3.09, mae=2.11, r2=-0.21
# [*] predict with currank model
# rmse=2.30, mae=1.29, r2=-0.11
# [*] predict with currank model
# rmse=2.30, mae=1.29, r2=-0.11
# [*] predict with avgrank model
# rmse=2.51, mae=1.73, r2=-0.31
# [*] predict with avgrank model
# rmse=2.51, mae=1.73, r2=-0.31
# [*] predict with dice model
# rmse=6.28, mae=4.42, r2=-7.24
# [*] predict with dice model
# rmse=6.28, mae=4.42, r2=-7.24
# [*] predict with lasso model
# rmse=2.16, mae=1.50, r2=0.03
# [*] predict with lasso model
# rmse=2.16, mae=1.50, r2=0.03
# [*] predict with ridge model
# rmse=2.21, mae=1.48, r2=-0.02
# [*] predict with ridge model
# rmse=2.21, mae=1.48, r2=-0.02
# [*] predict with rf model
# rmse=2.42, mae=1.72, r2=-0.22
# [*] predict with rf model
# rmse=2.21, mae=1.53, r2=-0.02
# [*] predict with svr model
# rmse=2.21, mae=1.36, r2=-0.02
# [*] predict with svr model
# rmse=2.21, mae=1.36, r2=-0.02
# [*] predict with xgb model
# rmse=2.69, mae=1.96, r2=-0.51
# [*] predict with xgb model
# rmse=2.69, mae=1.96, r2=-0.51
# [*] predict with currank model
# rmse=1.75, mae=1.19, r2=-0.27
# [*] predict with currank model
# rmse=1.75, mae=1.19, r2=-0.27
# [*] predict with avgrank model
# rmse=2.05, mae=1.52, r2=-0.75
# [*] predict with avgrank model
# rmse=2.05, mae=1.52, r2=-0.75
# [*] predict with dice model
# rmse=5.70, mae=4.44, r2=-12.50
# [*] predict with dice model
# rmse=5.70, mae=4.44, r2=-12.50
# [*] predict with lasso model
# rmse=1.84, mae=1.44, r2=-0.41
# [*] predict with lasso model
# rmse=1.84, mae=1.44, r2=-0.41
# [*] predict with ridge model
# rmse=1.68, mae=1.20, r2=-0.18
# [*] predict with ridge model
# rmse=1.68, mae=1.20, r2=-0.18
# [*] predict with rf model
# rmse=1.82, mae=1.28, r2=-0.38
# [*] predict with rf model
# rmse=1.95, mae=1.36, r2=-0.58
# [*] predict with svr model
# rmse=1.61, mae=1.20, r2=-0.08
# [*] predict with svr model
# rmse=1.61, mae=1.20, r2=-0.08
# [*] predict with xgb model
# rmse=2.53, mae=1.84, r2=-1.66
# [*] predict with xgb model
# rmse=2.53, mae=1.84, r2=-1.66

# %%
df_event_rmse
# Out:
#      runid trainsize testsize testdistribution   currank   avgrank      dice  \
# 0  Phoenix       691      114   +:39,0:20,-:55  5.428159  6.770844  7.162892
# 0  Indy500       580      225  +:88,0:23,-:114  5.748816  7.326274  6.832276
# 0    Texas       678      127   +:35,0:30,-:62  4.627885  6.539167  6.457005
# 0     Iowa       696      109   +:39,0:25,-:45  3.604279  4.912422  5.908321
# 0   Pocono       679      126   +:38,0:39,-:49  2.808717  3.517821  5.133148
# 0  Gateway       701      104   +:32,0:27,-:45  3.124038  4.335754  5.689903
#
#       lasso     ridge        rf       svr       xgb
# 0  4.976622  5.025101  5.091888  5.418394  5.105846
# 0  5.481805  5.483230  5.594891  5.752005  5.602743
# 0  4.474083  4.756342  5.143519  4.528277  4.910475
# 0  3.412080  3.494903  4.134058  3.602442  3.706305
# 0  3.004095  3.358958  2.997389  2.806152  2.827545
# 0  2.982362  3.058584  3.210711  3.095421  3.096799

# %%
df_event_r2
# Out:
#      runid trainsize testsize testdistribution   currank   avgrank      dice  \
# 0  Phoenix       691      114   +:39,0:20,-:55 -0.000316 -0.556387 -0.741842
# 0  Indy500       580      225  +:88,0:23,-:114 -0.003464 -0.629714 -0.417346
# 0    Texas       678      127   +:35,0:30,-:62 -0.006715 -1.009953 -0.959762
# 0     Iowa       696      109   +:39,0:25,-:45  0.000000 -0.857610 -1.687147
# 0   Pocono       679      126   +:38,0:39,-:49 -0.029595 -0.615094 -2.438887
# 0  Gateway       701      104   +:32,0:27,-:45 -0.001604 -0.929267 -2.322561
#
#       lasso     ridge        rf       svr       xgb
# 0  0.159183  0.142722  0.155055  0.003280  0.114950
# 0  0.087585  0.087111  0.077459 -0.004578  0.046883
# 0  0.059088 -0.063377 -0.237311  0.036155 -0.133413
# 0  0.103807  0.059771 -0.258684  0.001019 -0.057415
# 0 -0.177817 -0.472514 -0.402576 -0.027715 -0.043445
# 0  0.087183  0.039928 -0.033780  0.016662  0.015787

# %%
df_stage_rmse
# Out:
#     runid trainsize testsize   testdistribution   currank   avgrank      dice  \
# 0  stage0       153      652  +:213,0:140,-:299  4.356963  6.106830  6.932961
# 0  stage1       288      517  +:164,0:123,-:230  3.978910  4.957904  6.721742
# 0  stage2       421      384  +:113,0:103,-:168  3.849378  4.546786  6.792881
# 0  stage3       547      258    +:70,0:87,-:101  3.538821  4.118600  6.068408
# 0  stage4       657      148     +:31,0:52,-:65  3.093148  3.390338  5.322060
# 0  stage5       725       80     +:18,0:29,-:33  2.865746  3.247557  6.034277
# 0  stage6       767       38      +:6,0:16,-:16  2.299886  2.505592  6.278619
# 0  stage7       789       16        +:2,0:6,-:8  1.750000  2.049955  5.695393
#
#       lasso     ridge        rf       svr       xgb
# 0  4.411232  4.230496  4.806442  4.376090  5.225326
# 0  3.778881  3.741922  4.185232  4.009560  4.116786
# 0  3.560794  3.523728  3.788095  3.851122  3.884518
# 0  3.334479  3.297435  3.459451  3.558998  3.669002
# 0  2.922048  2.908027  2.915017  3.029977  2.991442
# 0  2.608161  2.684805  2.853844  2.810544  3.087544
# 0  2.159716  2.212388  2.416168  2.212289  2.687286
# 0  1.837558  1.683205  1.823945  1.607084  2.526081

# %%
df_stage_r2
# Out:
#     runid trainsize testsize   testdistribution   currank   avgrank  \
# 0  stage0       153      652  +:213,0:140,-:299 -0.005979 -0.976299
# 0  stage1       288      517  +:164,0:123,-:230 -0.001961 -0.555675
# 0  stage2       421      384  +:113,0:103,-:168 -0.003889 -0.400598
# 0  stage3       547      258    +:70,0:87,-:101 -0.002021 -0.357246
# 0  stage4       657      148     +:31,0:52,-:65 -0.052238 -0.264150
# 0  stage5       725       80     +:18,0:29,-:33 -0.043872 -0.340558
# 0  stage6       767       38      +:6,0:16,-:16 -0.105515 -0.312117
# 0  stage7       789       16        +:2,0:6,-:8 -0.274797 -0.749257
#
#         dice     lasso     ridge        rf       svr       xgb
# 0  -1.547174 -0.031195  0.051574 -0.211707 -0.014831 -0.446931
# 0  -1.859475  0.096249  0.113840 -0.079420 -0.017457 -0.072603
# 0  -2.126170  0.140990  0.158780  0.044056 -0.004799 -0.022301
# 0  -1.946518  0.110358  0.130015  0.031028 -0.013479 -0.077098
# 0  -2.115101  0.060953  0.069943  0.074812 -0.009697  0.015822
# 0  -3.628309  0.135349  0.083785 -0.070166 -0.004044 -0.211709
# 0  -7.239108  0.025133 -0.022997 -0.022425 -0.022906 -0.509315
# 0 -12.502439 -0.405552 -0.179340 -0.577795 -0.075083 -1.656193

# %% [markdown]
# ### save the model

# %%
import pickle 
eventsname = ['Phoenix','Indy500','Texas','Iowa','Pocono','Gateway']
events = set(stagedata['eventid'])
#for eventid in events:
eventid = 1
name = 'lasso'
valuemodel = 'valuemodel-' + eventsname[eventid] + '-lasso' + '.pkl'
if True:
    print('Testset = %s'%eventsname[eventid])
    
    train, test, train_x, train_y, test_x, test_y = split_by_eventid(stagedata, eventid)
    test_distribution = '+:%d,0:%d,-:%d'%(np.sum(test_y>0),np.sum(test_y==0),np.sum(test_y<0))
    #print('Testset by stageid= %s, trainsize=%d, testsize=%d, dist=%s'%
    #      (stageid, train_x.shape[0], test_x.shape[0], test_distribution))
    
    print('[*] predict with %s model'%name)
    clf = get_regressor(name)
    clf.fit(train_x, train_y)

    pred_y = clf.predict(test_x).astype(int)
    score = evaluate(test_y, pred_y)
    
    print('rec:', score)
    
    #save the model
    with open(valuemodel, 'wb') as fout:   
        pickle.dump((clf, test_x, test_y), fout)
# Out:
# Testset = Indy500
# [*] predict with lasso model
# rmse=5.44, mae=4.26, r2=0.10
# ('rec:', (5.4393627077688675, 4.262222222222222, 0.10165930556988323))
